# %%
import matplotlib. pyplot as plt
import numpy as np
plt.title("line plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
xpoints=np.array([0,20])
ypoints=np.array([5,20])
plt.plot(xpoints,ypoints)
plt.show()

# %%
plt.p
