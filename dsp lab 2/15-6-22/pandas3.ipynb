# %%
import pandas as pd
d=pd.read_csv("ap.csv")
d
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
d["Year"]
# Out:
# 0        2020
# 1        2020
# 2        2020
# 3        2020
# 4        2020
#          ...
# 37075    2013
# 37076    2013
# 37077    2013
# 37078    2013
# 37079    2013
# Name: Year, Length: 37080, dtype: int64

# %%
d[["Industry_name_NZSIOC","Industry_aggregation_NZSIOC"]]
# Out:
#              Industry_name_NZSIOC Industry_aggregation_NZSIOC
# 0                  All industries                     Level 1
# 1                  All industries                     Level 1
# 2                  All industries                     Level 1
# 3                  All industries                     Level 1
# 4                  All industries                     Level 1
# ...                           ...                         ...
# 37075  Food product manufacturing                     Level 3
# 37076  Food product manufacturing                     Level 3
# 37077  Food product manufacturing                     Level 3
# 37078  Food product manufacturing                     Level 3
# 37079  Food product manufacturing                     Level 3
#
# [37080 rows x 2 columns]

# %%
print(d.loc[5])
# Out:
# Year                                                                        2020
# Industry_aggregation_NZSIOC                                              Level 1
# Industry_code_NZSIOC                                                       99999
# Industry_name_NZSIOC                                              All industries
# Units                                                         Dollars (millions)
# Variable_code                                                                H09
# Variable_name                                             Interest and donations
# Variable_category                                          Financial performance
# Value                                                                     32,730
# Industry_code_ANZSIC06         ANZSIC06 divisions A-S (excluding classes K633...
# Name: 5, dtype: object

# %%
d.loc[9]
# Out:
# Year                                                                        2020
# Industry_aggregation_NZSIOC                                              Level 1
# Industry_code_NZSIOC                                                       99999
# Industry_name_NZSIOC                                              All industries
# Units                                                         Dollars (millions)
# Variable_code                                                                H13
# Variable_name                                           Redundancy and severance
# Variable_category                                          Financial performance
# Value                                                                        305
# Industry_code_ANZSIC06         ANZSIC06 divisions A-S (excluding classes K633...
# Name: 9, dtype: object

# %%
d.loc[3000]
# Out:
# Year                                                                        2020
# Industry_aggregation_NZSIOC                                              Level 3
# Industry_code_NZSIOC                                                        JJ11
# Industry_name_NZSIOC                                  Information Media Services
# Units                                                         Dollars (millions)
# Variable_code                                                                H21
# Variable_name                                                     Opening stocks
# Variable_category                                          Financial performance
# Value                                                                        162
# Industry_code_ANZSIC06         ANZSIC06 groups J541, J542, J551, J552, J561, ...
# Name: 3000, dtype: object

# %%
d["Industry_code_NZSIOC"]
# Out:
# 0        99999
# 1        99999
# 2        99999
# 3        99999
# 4        99999
#          ...
# 37075     ZZ11
# 37076     ZZ11
# 37077     ZZ11
# 37078     ZZ11
# 37079     ZZ11
# Name: Industry_code_NZSIOC, Length: 37080, dtype: object

# %%
d
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
d["address"]=0

# %%
d
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
d.loc[1000]
# Out:
# Year                                                                        2020
# Industry_aggregation_NZSIOC                                              Level 4
# Industry_code_NZSIOC                                                       CC523
# Industry_name_NZSIOC           Pharmaceutical, Cleaning and Other Chemical Ma...
# Units                                                         Dollars (millions)
# Variable_code                                                                H10
# Variable_name                                                     Indirect taxes
# Variable_category                                          Financial performance
# Value                                                                          7
# Industry_code_ANZSIC06                      ANZSIC06 groups C184, C185, and C189
# address                                                                        0
# Name: 1000, dtype: object

# %%
d.loc[5,"Variable_name"]
# Out:
# 'Interest and donations'

# %%
a=pd.read_csv("gow.csv")

# %%
a
# Out:
#         NAME  AGE  SUBJECT  MARKS
# 0      gowri   12    maths     95
# 1      priya   13  science     96
# 2    pallavi   16   social     56
# 3       ammu   23  english     89
# 4       gayu   45       wt     76
# ..       ...  ...      ...    ...
# 101     ammu   23  english     89
# 102     gayu   45       wt     76
# 103    valli   78     flat     67
# 104    divya   43       cd     89
# 105  lavanya   26       or     98
#
# [106 rows x 4 columns]

# %%
print(a.loc[4])
# Out:
# NAME       gayu
# AGE          45
# SUBJECT      wt
# MARKS        76
# Name: 4, dtype: object

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 4 columns):
# NAME       106 non-null object
# AGE        106 non-null int64
# SUBJECT    106 non-null object
# MARKS      106 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 3.4+ KB

# %%
a.describe
# Out:
# <bound method NDFrame.describe of         NAME  AGE  SUBJECT  MARKS
# 0      gowri   12    maths     95
# 1      priya   13  science     96
# 2    pallavi   16   social     56
# 3       ammu   23  english     89
# 4       gayu   45       wt     76
# ..       ...  ...      ...    ...
# 101     ammu   23  english     89
# 102     gayu   45       wt     76
# 103    valli   78     flat     67
# 104    divya   43       cd     89
# 105  lavanya   26       or     98
#
# [106 rows x 4 columns]>

# %%
a.count()
# Out:
# NAME       106
# AGE        106
# SUBJECT    106
# MARKS      106
# dtype: int64

# %%
a.max()
# Out:
# NAME       valli
# AGE           78
# SUBJECT       wt
# MARKS         98
# dtype: object

# %%
a.min()
# Out:
# NAME       ammu
# AGE          12
# SUBJECT      cd
# MARKS        56
# dtype: object

# %%
a.isnull()
# Out:
#       NAME    AGE  SUBJECT  MARKS
# 0    False  False    False  False
# 1    False  False    False  False
# 2    False  False    False  False
# 3    False  False    False  False
# 4    False  False    False  False
# ..     ...    ...      ...    ...
# 101  False  False    False  False
# 102  False  False    False  False
# 103  False  False    False  False
# 104  False  False    False  False
# 105  False  False    False  False
#
# [106 rows x 4 columns]

# %%
a.isnull().sum()
# Out:
# NAME       0
# AGE        0
# SUBJECT    0
# MARKS      0
# dtype: int64

# %%
a.head()
# Out:
#       NAME  AGE  SUBJECT  MARKS
# 0    gowri   12    maths     95
# 1    priya   13  science     96
# 2  pallavi   16   social     56
# 3     ammu   23  english     89
# 4     gayu   45       wt     76

# %%
a.tail()
# Out:
#         NAME  AGE  SUBJECT  MARKS
# 101     ammu   23  english     89
# 102     gayu   45       wt     76
# 103    valli   78     flat     67
# 104    divya   43       cd     89
# 105  lavanya   26       or     98

# %%
a["NAME"]
# Out:
# 0        gowri
# 1        priya
# 2      pallavi
# 3         ammu
# 4         gayu
#         ...
# 101       ammu
# 102       gayu
# 103      valli
# 104      divya
# 105    lavanya
# Name: NAME, Length: 106, dtype: object

# %%
a.loc[a["AGE"]>20]
# Out:
#         NAME  AGE  SUBJECT  MARKS
# 3       ammu   23  english     89
# 4       gayu   45       wt     76
# 5      valli   78     flat     67
# 6      divya   43       cd     89
# 7    lavanya   26       or     98
# ..       ...  ...      ...    ...
# 101     ammu   23  english     89
# 102     gayu   45       wt     76
# 103    valli   78     flat     67
# 104    divya   43       cd     89
# 105  lavanya   26       or     98
#
# [70 rows x 4 columns]

# %%
print(a.loc[a["AGE"]>20])
# Out:
#         NAME  AGE  SUBJECT  MARKS
# 3       ammu   23  english     89
# 4       gayu   45       wt     76
# 5      valli   78     flat     67
# 6      divya   43       cd     89
# 7    lavanya   26       or     98
# ..       ...  ...      ...    ...
# 101     ammu   23  english     89
# 102     gayu   45       wt     76
# 103    valli   78     flat     67
# 104    divya   43       cd     89
# 105  lavanya   26       or     98
#
# [70 rows x 4 columns]

# %%
a
# Out:
#         NAME  AGE  SUBJECT  MARKS
# 0      gowri   12    maths     95
# 1      priya   13  science     96
# 2    pallavi   16   social     56
# 3       ammu   23  english     89
# 4       gayu   45       wt     76
# ..       ...  ...      ...    ...
# 101     ammu   23  english     89
# 102     gayu   45       wt     76
# 103    valli   78     flat     67
# 104    divya   43       cd     89
# 105  lavanya   26       or     98
#
# [106 rows x 4 columns]

# %%
a["address"]=0

# %%
a
# Out:
#         NAME  AGE  SUBJECT  MARKS  address
# 0      gowri   12    maths     95        0
# 1      priya   13  science     96        0
# 2    pallavi   16   social     56        0
# 3       ammu   23  english     89        0
# 4       gayu   45       wt     76        0
# ..       ...  ...      ...    ...      ...
# 101     ammu   23  english     89        0
# 102     gayu   45       wt     76        0
# 103    valli   78     flat     67        0
# 104    divya   43       cd     89        0
# 105  lavanya   26       or     98        0
#
# [106 rows x 5 columns]

# %%
b=a[(a.AGE>20)&(a.MARKS>80)]

# %%
b
# Out:
#         NAME  AGE  SUBJECT  MARKS  address
# 3       ammu   23  english     89        0
# 6      divya   43       cd     89        0
# 7    lavanya   26       or     98        0
# 12      ammu   23  english     89        0
# 15     divya   43       cd     89        0
# 16   lavanya   26       or     98        0
# 21      ammu   23  english     89        0
# 24     divya   43       cd     89        0
# 25   lavanya   26       or     98        0
# 30      ammu   23  english     89        0
# 33     divya   43       cd     89        0
# 34   lavanya   26       or     98        0
# 39      ammu   23  english     89        0
# 42     divya   43       cd     89        0
# 43   lavanya   26       or     98        0
# 48      ammu   23  english     89        0
# 51     divya   43       cd     89        0
# 52   lavanya   26       or     98        0
# 57      ammu   23  english     89        0
# 60     divya   43       cd     89        0
# 61   lavanya   26       or     98        0
# ...

# %%
a["NAME"]
# Out:
# 0        gowri
# 1        priya
# 2      pallavi
# 3         ammu
# 4         gayu
#         ...
# 101       ammu
# 102       gayu
# 103      valli
# 104      divya
# 105    lavanya
# Name: NAME, Length: 106, dtype: object

# %%
a.loc[1,"NAME"]
# Out:
# 'priya'

# %%
a.loc[1]
# Out:
# NAME         priya
# AGE             13
# SUBJECT    science
# MARKS           96
# address          0
# Name: 1, dtype: object

# %%
a.loc[0]
# Out:
# NAME       gowri
# AGE           12
# SUBJECT    maths
# MARKS         95
# address        0
# Name: 0, dtype: object

# %%
a.loc[6]
# Out:
# NAME       divya
# AGE           43
# SUBJECT       cd
# MARKS         89
# address        0
# Name: 6, dtype: object

# %%
a=pd.read_csv("gow.csv")
a.to_excel("priya.xlsx")
a=pd.read_excel("priya.xlsx")
a
# Out:
#      Unnamed: 0     NAME  AGE  SUBJECT  MARKS
# 0             0    gowri   12    maths     95
# 1             1    priya   13  science     96
# 2             2  pallavi   16   social     56
# 3             3     ammu   23  english     89
# 4             4     gayu   45       wt     76
# ..          ...      ...  ...      ...    ...
# 101         101     ammu   23  english     89
# 102         102     gayu   45       wt     76
# 103         103    valli   78     flat     67
# 104         104    divya   43       cd     89
# 105         105  lavanya   26       or     98
#
# [106 rows x 5 columns]

# %%
print(a)
# Out:
#      Unnamed: 0     NAME  AGE  SUBJECT  MARKS
# 0             0    gowri   12    maths     95
# 1             1    priya   13  science     96
# 2             2  pallavi   16   social     56
# 3             3     ammu   23  english     89
# 4             4     gayu   45       wt     76
# ..          ...      ...  ...      ...    ...
# 101         101     ammu   23  english     89
# 102         102     gayu   45       wt     76
# 103         103    valli   78     flat     67
# 104         104    divya   43       cd     89
# 105         105  lavanya   26       or     98
#
# [106 rows x 5 columns]
